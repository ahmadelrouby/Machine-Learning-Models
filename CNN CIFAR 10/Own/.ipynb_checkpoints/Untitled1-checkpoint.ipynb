# %%
import pyximport
pyximport.install()

from conv_layer import ConvolutionalLayer
from dense import Dense
from max_pool_layer import MaxPool
from relu_activation import Relu
from softmax_activation import Softmax
from flatten import Flatten
from model import Model
from data_utils import *



data = get_CIFAR10_data()
# Out:
# Training data shape:  (50000, 32, 32, 3)
# Training labels shape:  (50000,)
# Test data shape:  (10000, 32, 32, 3)
# Test labels shape:  (10000,)
# Before Augmentation
# Training data shape:  (50000, 32, 32, 3)
# Training labels shape:  (50000,)
# Test data shape:  (10000, 32, 32, 3)
# Test labels shape:  (10000,)

# %%
with open("model.file", "rb") as f:
    model = pickle.load(f)

# %%
test_acc = model.check_accuracy(data['X_test'],data['y_test'])

# %%
print (test_acc)
# Out:
# 0.4713

# %%
model.train()
# Out:
# Epoch:  0----------------------------------------------------] 0.0% ...Loss: 1.5291587918434835
# Training Accuracy:  0.454
# Validation Accuracy:  0.492
# Epoch:  1====================================================] 99.5% ...Loss: 1.5676866316816158
# Training Accuracy:  0.481
# Validation Accuracy:  0.498
# Epoch:  2====================================================] 99.5% ...Loss: 1.5308576687259847
# Training Accuracy:  0.489
# Validation Accuracy:  0.496
# [===================================-------------------------] 57.7% ...Loss: 1.5139508389275618
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-22a9f6312119> in <module>()
# ----> 1 model.train()
#
# ~/Documents/Machine Learning/New/Assignment_3/model.py in train(self)
#     152
#     153         for t in range(num_iterations):
# --> 154             self.step()
#     155
#     156             training_num += 1
#
# ~/Documents/Machine Learning/New/Assignment_3/model.py in step(self)
#     132         for i in reversed(range(num_layers-1)):
#     133             #start_time = time.time()
# --> 134             dx = self.layers[i].backward(dx)
#     135             #elapsed_time = time.time() - start_time
#     136             #print ('Layer: ', self.layers[i].name , ' took ' , str(elapsed_time) , ' to backward.\n')
#
# ~/Documents/Machine Learning/New/Assignment_3/dense.py in backward(self, dout)
#      47         self.Bias_grad = db
#      48
# ---> 49         self.Weight = self.Weight_opt.update(self.Weight,self.Weight_grad)
#      50         self.Bias = self.Bias_opt.update(self.Bias,self.Bias_grad)
#      51
#
# ~/Documents/Machine Learning/New/Assignment_3/adam_optimizer.py in update(self, x, dx)
#      38         m = m + temp
#      39
# ---> 40         v = beta2 * v + (1 - beta2) * (dx**2)
#      41
#      42
#
# KeyboardInterrupt:

# %%
import pickle
with open("model.file", "wb") as f:
    pickle.dump(model, f, pickle.HIGHEST_PROTOCOL)
